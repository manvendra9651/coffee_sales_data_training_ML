# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"E:\Practice_Datasets\car_prices.csv")
df
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
df.head()
# Out:
#    year   make                model        trim   body transmission  \
# 0  2015    Kia              Sorento          LX    SUV    automatic
# 1  2015    Kia              Sorento          LX    SUV    automatic
# 2  2014    BMW             3 Series  328i SULEV  Sedan    automatic
# 3  2015  Volvo                  S60          T5  Sedan    automatic
# 4  2014    BMW  6 Series Gran Coupe        650i  Sedan    automatic
#
#                  vin state  condition  odometer  color interior  \
# 0  5xyktca69fg566472    ca        5.0   16639.0  white    black
# 1  5xyktca69fg561319    ca        5.0    9393.0  white    beige
# 2  wba3c1c51ek116351    ca       45.0    1331.0   gray    black
# 3  yv1612tb4f1310987    ca       41.0   14282.0  white    black
# 4  wba6b2c57ed129731    ca       43.0    2641.0   gray    black
#
#                                    seller      mmr  sellingprice  \
# 0                 kia motors america  inc  20500.0       21500.0
# ...

# %%
df.describe()
# Out:
#                 year      condition       odometer            mmr  \
# count  558837.000000  547017.000000  558743.000000  558799.000000
# mean     2010.038927      30.672365   68320.017767   13769.377495
# std         3.966864      13.402832   53398.542821    9679.967174
# min      1982.000000       1.000000       1.000000      25.000000
# 25%      2007.000000      23.000000   28371.000000    7100.000000
# 50%      2012.000000      35.000000   52254.000000   12250.000000
# 75%      2013.000000      42.000000   99109.000000   18300.000000
# max      2015.000000      49.000000  999999.000000  182000.000000
#
#         sellingprice
# count  558825.000000
# mean    13611.358810
# std      9749.501628
# min         1.000000
# 25%      6900.000000
# 50%     12100.000000
# 75%     18200.000000
# max    230000.000000

# %%
df.isnull().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
df['make'].fillna(df['make'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\3203144837.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['make'].fillna(df['make'].mode()[0] , inplace=True)

# %%
df['model'].fillna(df['model'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\3297407305.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['model'].fillna(df['model'].mode()[0] , inplace=True)

# %%
df['trim'].fillna(df['trim'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\2470324116.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['trim'].fillna(df['trim'].mode()[0] , inplace=True)

# %%
df['body'].fillna(df['body'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\151708838.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['body'].fillna(df['body'].mode()[0] , inplace=True)

# %%
df.isnull().sum()
# Out:
# year                0
# make                0
# model               0
# trim                0
# body                0
# transmission    65352
# vin                 4
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
df['transmission'].fillna(df['transmission'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\1247583229.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['transmission'].fillna(df['transmission'].mode()[0] , inplace=True)

# %%
df['vin'].fillna(df['vin'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\1873426470.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['vin'].fillna(df['vin'].mode()[0] , inplace=True)

# %%
df.isnull().sum()
# Out:
# year                0
# make                0
# model               0
# trim                0
# body                0
# transmission        0
# vin                 0
# state               0
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
df['condition'].fillna(df['condition'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\387595824.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['condition'].fillna(df['condition'].mode()[0] , inplace=True)

# %%
df['odometer'].fillna(df['odometer'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\2552363440.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['odometer'].fillna(df['odometer'].mode()[0] , inplace=True)

# %%
df['color'].fillna(df['color'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\1464580934.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['color'].fillna(df['color'].mode()[0] , inplace=True)

# %%
df['interior'].fillna(df['interior'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\1486246771.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['interior'].fillna(df['interior'].mode()[0] , inplace=True)

# %%
df.isnull().sum()
# Out:
# year             0
# make             0
# model            0
# trim             0
# body             0
# transmission     0
# vin              0
# state            0
# condition        0
# odometer         0
# color            0
# interior         0
# seller           0
# mmr             38
# sellingprice    12
# saledate        12
# dtype: int64

# %%
df['mmr'].fillna(df['mmr'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\3507332208.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['mmr'].fillna(df['mmr'].mode()[0] , inplace=True)

# %%
df['sellingprice'].fillna(df['sellingprice'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\1945360547.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['sellingprice'].fillna(df['sellingprice'].mode()[0] , inplace=True)

# %%
df['saledate'].fillna(df['saledate'].mode()[0] , inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\3652243543.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['saledate'].fillna(df['saledate'].mode()[0] , inplace=True)

# %%
df.isnull().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# transmission    0
# vin             0
# state           0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %% [markdown]
# df.tail()

# %%
df.columns
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate'],
#       dtype='object')

# %%
df.shape
# Out:
# (558837, 16)

# %%
df.rename(columns={'make':'Manufacturer'}, inplace=True)

# %%
df
# Out:
#         year Manufacturer                model         trim       body  \
# 0       2015          Kia              Sorento           LX        SUV
# 1       2015          Kia              Sorento           LX        SUV
# 2       2014          BMW             3 Series   328i SULEV      Sedan
# 3       2015        Volvo                  S60           T5      Sedan
# 4       2014          BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...          ...                  ...          ...        ...
# 558832  2015          Kia                 K900       Luxury      Sedan
# 558833  2012          Ram                 2500  Power Wagon   Crew Cab
# 558834  2012          BMW                   X5    xDrive35d        SUV
# 558835  2015       Nissan               Altima        2.5 S      sedan
# 558836  2014         Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# ...

# %%
df['Manufacturer'].value_counts()
# Out:
# Manufacturer
# Ford          103855
# Chevrolet      60197
# Nissan         53946
# Toyota         39871
# Dodge          30710
#                ...
# ford tk            1
# chev truck         1
# airstream          1
# dot                1
# Lotus              1
# Name: count, Length: 96, dtype: int64

# %%
df['body'].value_counts()
# Out:
# body
# Sedan          212632
# SUV            119292
# sedan           41906
# suv             24552
# Hatchback       21380
#                 ...
# CTS-V Wagon         1
# Ram Van             1
# g37 coupe           1
# cab plus 4          1
# cts wagon           1
# Name: count, Length: 87, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# transmission
# automatic    541267
# manual        17544
# sedan            15
# Sedan            11
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# black        111719
# white        106673
# silver        83389
# gray          82857
# blue          51139
# red           43569
# —             24685
# green         11382
# gold          11342
# beige          9222
# burgundy       8972
# brown          6717
# orange         2078
# purple         1561
# off-white      1449
# yellow         1285
# charcoal        479
# turquoise       236
# pink             42
# lime             15
# 4802              1
# 9410              1
# 1167              1
# 2172              1
# 14872             1
# 12655             1
# 15719             1
# 6388              1
# 16633             1
# 11034             1
# 2711              1
# 6864              1
# 339               1
# 18384             1
# 9887              1
# 9837              1
# 20379             1
# 20627             1
# 721               1
# 6158              1
# 2817              1
# 5705              1
# 18561             1
# 2846              1
# 9562              1
# ...

# %%
df['model'].value_counts()
# Out:
# model
# Altima        29748
# F-150         14479
# Fusion        12946
# Camry         12545
# Escape        11861
#               ...
# Q3                1
# F-250             1
# 360               1
# TLX               1
# 458 Italia        1
# Name: count, Length: 973, dtype: int64

# %%
df['seller'].value_counts()
# Out:
# seller
# nissan-infiniti lt               19693
# ford motor credit company llc    19162
# the hertz corporation            18299
# santander consumer               15285
# avis corporation                 12540
#                                  ...
# jimmy auto sale llc                  1
# flynns auto sls & serv inc           1
# ruthrauff auto sales llc             1
# lsk automotive llc                   1
# auto rental etc                      1
# Name: count, Length: 14263, dtype: int64

# %%
df['trim'].value_counts()
# Out:
# trim
# Base           66468
# SE             43648
# LX             20757
# Limited        18367
# LT             16915
#                ...
# Estate             1
# ZX5 Premium        1
# Power Wagon        1
# RE:FLEX            1
# TSI SE             1
# Name: count, Length: 1963, dtype: int64

# %%
df['state'].value_counts()
# Out:
# state
# fl                   82945
# ca                   73148
# pa                   53907
# tx                   45913
# ga                   34750
#                      ...
# 3vwd17aj4fm236636        1
# 3vwd17aj5fm225953        1
# 3vwd17aj7fm326640        1
# 3vwd17aj8fm239622        1
# 3vwd17aj2fm261566        1
# Name: count, Length: 64, dtype: int64

# %%
df['transmission'].hist(bins=20)
# Out:
# <Axes: >

# %%
df['sellingprice'].mean()
# Out:
# np.float64(13611.302735860367)

# %%
df.nlargest(10, 'sellingprice')
# Out:
#         year   Manufacturer       model      trim   body transmission  \
# 344905  2014           Ford      Escape  Titanium    SUV    automatic
# 548169  2011        Ferrari  458 Italia      Base  coupe    automatic
# 446949  2015  Mercedes-Benz     S-Class   S65 AMG  Sedan    automatic
# 545523  2013    Rolls-Royce       Ghost      Base  sedan    automatic
# 125095  2012    Rolls-Royce       Ghost      Base  Sedan    automatic
# 557570  2012    Rolls-Royce       Ghost       EWB  sedan    automatic
# 538347  2012    Rolls-Royce       Ghost      Base  sedan    automatic
# 146917  2014            BMW          i8      Base  Coupe    automatic
# 283534  2014            BMW          i8      Base  Coupe    automatic
# 194349  2011    Rolls-Royce       Ghost      Base  Sedan    automatic
#
#                       vin state  condition  odometer  color interior  \
# 344905  1fmcu9j98eua23833    mo       43.0   27802.0  green      tan
# ...

# %%
df.groupby('state')['sellingprice'].sum()
# Out:
# state
# 3vwd17aj0fm227318        13700.0
# 3vwd17aj2fm258506        13300.0
# 3vwd17aj2fm261566        13400.0
# 3vwd17aj2fm285365        14050.0
# 3vwd17aj3fm259017        14250.0
#                         ...
# tx                   606495361.0
# ut                    22152489.0
# va                   103133220.0
# wa                   103419009.0
# wi                   137948766.0
# Name: sellingprice, Length: 64, dtype: float64

# %%
df.groupby('year')['sellingprice'].mean()
# Out:
# year
# 1982    12750.000000
# 1983     5250.000000
# 1984     2160.000000
# 1985     3520.000000
# 1986     2538.636364
# 1987     1512.500000
# 1988     3168.181818
# 1989     1620.000000
# 1990     1435.714286
# 1991      943.656716
# 1992      991.666667
# 1993      833.902439
# 1994      870.599490
# 1995      913.292546
# 1996      985.781434
# 1997     1157.454722
# 1998     1261.719404
# 1999     1533.696105
# 2000     1827.834130
# 2001     2131.014224
# 2002     2611.709315
# 2003     3447.268654
# 2004     4321.474455
# 2005     4893.989857
# 2006     6190.204808
# 2007     8021.969687
# 2008     9508.054092
# 2009    10462.313295
# 2010    12412.453313
# 2011    15851.677185
# 2012    16653.639320
# 2013    17476.074902
# 2014    20089.976280
# 2015    25932.117198
# Name: sellingprice, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   Manufacturer  558837 non-null  object
#  2   model         558837 non-null  object
#  3   trim          558837 non-null  object
#  4   body          558837 non-null  object
#  5   transmission  558837 non-null  object
#  6   vin           558837 non-null  object
#  7   state         558837 non-null  object
#  8   condition     558837 non-null  float64
#  9   odometer      558837 non-null  float64
#  10  color         558837 non-null  object
#  11  interior      558837 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558837 non-null  float64
#  14  sellingprice  558837 non-null  float64
#  15  saledate      558837 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
df['color'].value_counts().head(30).plot(kind='barh',color='orange',edgecolor='black')
plt.figure(figsize=(20, 15))
plt.title('Top 30 car colors', fontsize=15)
plt.xlabel('count',fontsize=15)
plt.ylabel('count',fontsize=15)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df, y='color',palette='viridis')
plt.xticks(rotation=45)
plt.title('count of each color')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17644\2930687748.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='color',palette='viridis')

# %%
sns.scatterplot(x='condition', y='sellingprice', data=df)
# Out:
# <Axes: xlabel='condition', ylabel='sellingprice'>

# %%
sns.scatterplot(x='odometer', y='sellingprice', data=df)
# Out:
# <Axes: xlabel='odometer', ylabel='sellingprice'>

# %%
sns.scatterplot(x='mmr', y='sellingprice', data=df)
# Out:
# <Axes: xlabel='mmr', ylabel='sellingprice'>

# %%
X = df[['year','condition','odometer','mmr']]
y = df['sellingprice']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([25728.26918142, 16576.90366952, 19678.88594857, ...,
#          393.72056702, 12199.18915282,   -76.95022117])

# %%
pip install streamlit
# Out:
# ...
#
# ...

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Title
st.title("Car Sales Dashboard")

# Data Load
df = pd.read_csv(r"E:\Practice_Datasets\car_prices.csv")

# Show data
st.subheader("Dataset")
st.write(df.head())

# Brand filter
brand = st.selectbox("Select Car Brand", df['make'].unique())

filtered_data = df[df['make'] == brand]

st.write(filtered_data)
# Out:
# 2026-04-06 12:19:21.114 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:24.566
# ...
#   command:
#
#     streamlit run C:\Users\DELL\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-04-06 12:19:24.569 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:29.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:29.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:29.151 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:29.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
st.subheader("Selling Price Distribution")

fig, ax = plt.subplots()
sns.histplot(df['sellingprice'], bins=30, ax=ax)

st.pyplot(fig)
# Out:
# 2026-04-06 12:19:29.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:29.511 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:31.022 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:31.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:31.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.subheader("Top Car Brands")

brand_count = df['make'].value_counts().head(10)

fig, ax = plt.subplots()
brand_count.plot(kind='bar', ax=ax)

st.pyplot(fig)
# Out:
# 2026-04-06 12:19:31.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:31.905 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:32.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:32.562 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:32.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
st.subheader("Odometer vs Selling Price")

fig, ax = plt.subplots()
sns.scatterplot(x='odometer', y='sellingprice', data=df, ax=ax)

st.pyplot(fig)
# Out:
# 2026-04-06 12:19:32.588 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:32.596 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:34.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:40.565 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 12:19:40.568 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
